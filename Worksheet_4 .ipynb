# %% [markdown]
# # Loading and Preprocessing MNIST Handwritten Digit Dataset:

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
print(x_train.shape)

x_train = x_train.reshape(-1, 28 * 28)
x_test = x_test.reshape(-1, 28 * 28)

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# (60000, 28, 28)

# %% [markdown]
# # Build the Model:

# %% [markdown]
# ## 1. Sequential API

# %%
# Model parameters
import tensorflow as tf
from tensorflow import keras
num_classes = 10
input_shape = (28*28, )
model = keras.Sequential(
[
keras.layers.Input(shape=input_shape),
keras.layers.Flatten(), # Flatten the 28x28 image to a 784-dimensional vector
keras.layers.Dense(64, activation="sigmoid"),
keras.layers.Dense(128, activation="sigmoid"),
keras.layers.Dense(256, activation="sigmoid"),
keras.layers.Dense(num_classes, activation="softmax"),
]
)

# %%
model.summary()
# 784 * 64 + 64 = 50,240
# 64 * 128 + 128 + 8,320
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
optimizer="sgd", # Stochastic Gradient Descent
loss="categorical_crossentropy", # Loss function for multi-class classification
metrics=["accuracy"] # Track accuracy during training
)

# %%
batch_size = 128 # no.of batch - total/ batch_size
epochs = 100
# Callbacks
callbacks = [
  keras.callbacks.ModelCheckpoint(filepath="model_at_epoch_{epoch}.keras"),
  keras.callbacks.EarlyStopping(monitor="val_loss", patience=4 ),
]
# Train the model with callbacks and validation split
history = model.fit(
  x_train,
  y_train,
  batch_size=batch_size,
  epochs=epochs,
  validation_split=0.15,
  callbacks=callbacks,
)
# Out:
# Epoch 1/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.1127 - loss: 2.3059 - val_accuracy: 0.1063 - val_loss: 2.3023
# Epoch 2/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.1155 - loss: 2.2999 - val_accuracy: 0.1063 - val_loss: 2.2996
# Epoch 3/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1172 - loss: 2.2983 - val_accuracy: 0.0959 - val_loss: 2.2998
# Epoch 4/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1190 - loss: 2.2969 - val_accuracy: 0.1069 - val_loss: 2.2965
# Epoch 5/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1258 - loss: 2.2951 - val_accuracy: 0.1063 - val_loss: 2.2952
# Epoch 6/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1266 - loss: 2.2934 - val_accuracy: 0.1063 - val_loss: 2.2936
# Epoch 7/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.1339 - loss: 2.2913 - val_accuracy: 0.1063 - val_loss: 2.2906
# Epoch 8/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.1345 - loss: 2.2890 - val_accuracy: 0.1063 - val_loss: 2.2889
# Epoch 9/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1420 - loss: 2.2861 - val_accuracy: 0.1723 - val_loss: 2.2863
# Epoch 10/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1503 - loss: 2.2832 - val_accuracy: 0.1172 - val_loss: 2.2823
# Epoch 11/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1586 - loss: 2.2795 - val_accuracy: 0.1453 - val_loss: 2.2763
# Epoch 12/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1793 - loss: 2.2749 - val_accuracy: 0.1623 - val_loss: 2.2716
# Epoch 13/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.1872 - loss: 2.2696 - val_accuracy: 0.1099 - val_loss: 2.2671
# Epoch 14/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1987 - loss: 2.2631 - val_accuracy: 0.2602 - val_loss: 2.2606
# Epoch 15/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2394 - loss: 2.2548 - val_accuracy: 0.2821 - val_loss: 2.2485
# Epoch 16/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2602 - loss: 2.2441 - val_accuracy: 0.2821 - val_loss: 2.2365
# Epoch 17/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2935 - loss: 2.2302 - val_accuracy: 0.4077 - val_loss: 2.2223
# Epoch 18/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3235 - loss: 2.2120 - val_accuracy: 0.3639 - val_loss: 2.2002
# Epoch 19/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.3506 - loss: 2.1872 - val_accuracy: 0.4556 - val_loss: 2.1699
# Epoch 20/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.3676 - loss: 2.1528 - val_accuracy: 0.3570 - val_loss: 2.1307
# Epoch 21/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0
100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8852 - loss: 0.4129 - val_accuracy: 0.8946 - val_loss: 0.3732
# Epoch 87/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8860 - loss: 0.4096 - val_accuracy: 0.8944 - val_loss: 0.3701
# Epoch 88/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8868 - loss: 0.4064 - val_accuracy: 0.8954 - val_loss: 0.3676
# Epoch 89/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8876 - loss: 0.4033 - val_accuracy: 0.8967 - val_loss: 0.3645
# Epoch 90/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8888 - loss: 0.4001 - val_accuracy: 0.8963 - val_loss: 0.3615
# Epoch 91/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8894 - loss: 0.3970 - val_accuracy: 0.8976 - val_loss: 0.3590
# Epoch 92/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8901 - loss: 0.3940 - val_accuracy: 0.8991 - val_loss: 0.3566
# Epoch 93/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8916 - loss: 0.3909 - val_accuracy: 0.9000 - val_loss: 0.3537
# Epoch 94/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8919 - loss: 0.3880 - val_accuracy: 0.9008 - val_loss: 0.3511
# Epoch 95/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8928 - loss: 0.3848 - val_accuracy: 0.9016 - val_loss: 0.3495
# Epoch 96/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8936 - loss: 0.3822 - val_accuracy: 0.9031 - val_loss: 0.3456
# Epoch 97/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8940 - loss: 0.3791 - val_accuracy: 0.9034 - val_loss: 0.3432
# Epoch 98/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8953 - loss: 0.3764 - val_accuracy: 0.9042 - val_loss: 0.3404
# Epoch 99/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8957 - loss: 0.3735 - val_accuracy: 0.9056 - val_loss: 0.3386
# Epoch 100/100
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8967 - loss: 0.3707 - val_accuracy: 0.9040 - val_loss: 0.3360

# %%
import matplotlib.pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']

train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss', color='blue')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_acc) + 1), train_acc, label='Training Accuracy', color='blue')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.8991 - loss: 0.3565
# Test accuracy: 0.8991

# %% [markdown]
# # Exercise: Building a Fully Connected Network (FCN) for Devnagari Digit Classification.

# %% [markdown]
# ## Task 1: Data Preparation

# %% [markdown]
# ### Loading libraries and extraction

# %%
import os
import numpy as np
from PIL import Image
from tensorflow.keras.utils import to_categorical

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/AI and ML/Week 4/devnagari digit.zip"
extract_path = "/content/devnagari"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction done!")
# Out:
# Extraction done!

# %%
base_path = "/content/devnagari/DevanagariHandwrittenDigitDataset"

train_dir = os.path.join(base_path, "Train")
test_dir = os.path.join(base_path, "Test")

# %% [markdown]
# ### Load and read image files

# %%
from PIL import Image
import numpy as np

def load_data(data_dir, img_size=(28, 28)):
    X = []
    y = []

    for folder in os.listdir(data_dir):
        folder_path = os.path.join(data_dir, folder)

        if not os.path.isdir(folder_path):
            continue

        # Extract label from "digit_3" → 3
        label = int(folder.split("_")[1])

        for file in os.listdir(folder_path):
            img_path = os.path.join(folder_path, file)

            try:
                img = Image.open(img_path).convert('L')  # grayscale
                img = img.resize(img_size)
                img_array = np.array(img)

                X.append(img_array)
                y.append(label)

            except:
                continue

    return np.array(X), np.array(y)

# %% [markdown]
# ### Loss Train/Test Data and normalize

# %%
X_train, y_train = load_data(train_dir)
X_test, y_test = load_data(test_dir)

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ### Flatten for FCN

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# %% [markdown]
# ### One-Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

num_classes = 10  # digits 0–9

y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (17000, 784)
# y_train: (17000, 10)
# X_test: (3000, 784)
# y_test: (3000, 10)

# %% [markdown]
# ## Task 2: Build FCN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

# Input layer and Hidden Layer 1
model.add(Dense(64, activation='sigmoid', input_shape=(784,)))
# Hidden Layer 2
model.add(Dense(128, activation='sigmoid'))
# Hidden Layer 3
model.add(Dense(256, activation='sigmoid'))
# Output Layer
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Task 3: Compile the model

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Task 4: Train

# %%
history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4322 - loss: 1.7249 - val_accuracy: 0.0000e+00 - val_loss: 6.6349
# Epoch 2/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8212 - loss: 0.6066 - val_accuracy: 0.0000e+00 - val_loss: 7.3003
# Epoch 3/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9149 - loss: 0.2906 - val_accuracy: 0.0000e+00 - val_loss: 7.9442
# Epoch 4/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9473 - loss: 0.1865 - val_accuracy: 0.0000e+00 - val_loss: 8.5204
# Epoch 5/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9600 - loss: 0.1402 - val_accuracy: 0.0000e+00 - val_loss: 8.7610
# Epoch 6/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9693 - loss: 0.1110 - val_accuracy: 0.0000e+00 - val_loss: 8.9840
# Epoch 7/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9741 - loss: 0.0919 - val_accuracy: 0.0000e+00 - val_loss: 9.5384
# Epoch 8/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9785 - loss: 0.0781 - val_accuracy: 0.0000e+00 - val_loss: 9.3417
# Epoch 9/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9831 - loss: 0.0668 - val_accuracy: 0.0000e+00 - val_loss: 9.8054
# Epoch 10/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9855 - loss: 0.0553 - val_accuracy: 0.0000e+00 - val_loss: 9.9107
# Epoch 11/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9885 - loss: 0.0471 - val_accuracy: 0.0000e+00 - val_loss: 9.9141
# Epoch 12/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9900 - loss: 0.0395 - val_accuracy: 0.0000e+00 - val_loss: 10.2909
# Epoch 13/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9923 - loss: 0.0329 - val_accuracy: 0.0000e+00 - val_loss: 10.3050
# Epoch 14/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9937 - loss: 0.0285 - val_accuracy: 0.0000e+00 - val_loss: 10.4393
# Epoch 15/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9951 - loss: 0.0234 - val_accuracy: 0.0000e+00 - val_loss: 10.4931
# Epoch 16/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9962 - loss: 0.0197 - val_accuracy: 0.0000e+00 - val_loss: 10.6215
# Epoch 17/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9968 - loss: 0.0163 - val_accuracy: 0.0000e+00 - val_loss: 10.9550
# Epoch 18/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9982 - loss: 0.0129 - val_accuracy: 0.0000e+00 - val_loss: 10.9381
# Epoch 19/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9988 - loss: 0.0106 - val_accuracy: 0.0000e+00 - val_loss: 11.2075
# Epoch 20/20
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9993 - loss: 0.0088 - val_accuracy: 0.0000e+00 - val_loss: 11.1694

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

# Accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
# Loss graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# %% [markdown]
# # Task 5: Evaluation

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7837 - loss: 2.3189
# Test Loss: 2.3189165592193604
# Test Accuracy: 0.7836666703224182

# %% [markdown]
# # Task 6: Save and Load the Model

# %%
model.save("devnagari_fcn_model.keras")
print("Model saved!")
# Out:
# Model saved!

# %%
from tensorflow.keras.models import load_model

loaded_model = load_model("devnagari_fcn_model.h5")
print("Model loaded successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!

# %%
loss, accuracy = loaded_model.evaluate(X_test, y_test)

print("Test Data Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7837 - loss: 2.3189
# Test Loss: 2.3189165592193604
# Test Accuracy: 0.7836666703224182

# %% [markdown]
# # Task 7: Predictions

# %%
predictions = loaded_model.predict(X_test)

# Convert probabilities → labels
predicted_labels = np.argmax(predictions, axis=1)

# True labels (convert from one-hot)
true_labels = np.argmax(y_test, axis=1)

print("Predicted:", predicted_labels[:10])
print("Actual:", true_labels[:10])
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Predicted: [3 3 2 3 3 3 3 3 3 3]
# Actual: [3 3 3 3 3 3 3 3 3 3]
